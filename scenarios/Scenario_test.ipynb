# %%
import BPTK_Py
bptk = BPTK_Py.bptk()

scenario_manager={
    "sddsl_customer_acquisition":{
        "model":"Customer Acquisition SDDSL",
        "base_constants":{
            "initial_customers" : 0.0,
            "initial_potential_customers" : 60000.0,
            "advertising_success": 0.1,
            "consumers_reached_per_euro" : 100.0,
            "advertising_budget" : 100.0,
            "word_of_mouth_success": 0.01,
            "contact_rate" : 10.0
        }
    }
}


bptk.register_scenario_manager(scenario_manager)

bptk.register_scenarios(
    
    scenario_manager="sddsl_customer_acquisition",
    scenarios=
    {
        "base":{
            
        },
        "low_word_of_mouth":{
            "constants":{
                "word_of_mouth_success":0.001
            }
        },
        "high_word_of_mouth":{
            "constants":{
                "word_of_mouth_success":0.1
            }
        },
        "interactive_scenario":{}
        
    }
    

)

bptk.plot_scenarios(
    scenario_managers=["sddsl_customer_acquisition"],
    scenarios=["base","low_word_of_mouth","high_word_of_mouth"],
    equations=["customers"],
    series_names={
        "sddsl_customer_acquisition_base_customers":"Base",
        "sddsl_customer_acquisition_low_word_of_mouth_customers":"Low Word of Mouth",
        "sddsl_customer_acquisition_high_word_of_mouth_customers":"High Word of Mouth",
    }
)
# Out:
# 2026-02-10 15:24:12.939376, [ERROR] Module not found Error when trying to load simulation class from external file. Only use relative paths and do not rename the class inside the generated class! Error Message: Empty module name
# 2026-02-10 15:24:12.947754, [ERROR] Module not found Error when trying to load simulation class from external file. Only use relative paths and do not rename the class inside the generated class! Error Message: Empty module name
# 2026-02-10 15:24:12.947754, [ERROR] Module not found Error when trying to load simulation class from external file. Only use relative paths and do not rename the class inside the generated class! Error Message: Empty module name
# 2026-02-10 15:24:12.958391, [ERROR] Module not found Error when trying to load simulation class from external file. Only use relative paths and do not rename the class inside the generated class! Error Message: Empty module name
# 2026-02-10 15:24:12.960635, [ERROR] No scenarios found for scenario managers "sddsl_customer_acquisition" and scenarios ""
# 2026-02-10 15:24:12.966717, [ERROR] No scenario found for scenario_managers=['sddsl_customer_acquisition'] and scenario_names=[]. Cancelling
# 2026-02-10 15:24:12.966717, [ERROR] Scenario "base" not found in any scenario manager!
# 2026-02-10 15:24:12.966717, [ERROR] Scenario "low_word_of_mouth" not found in any scenario manager!
# 2026-02-10 15:24:12.972306, [ERROR] Scenario "high_word_of_mouth" not found in any scenario manager!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 47
#      20 bptk.register_scenario_manager(scenario_manager)
#      22 bptk.register_scenarios(
#      23
#      24     scenario_manager="sddsl_customer_acquisition",
#    (...)     44
#      45 )
# ---> 47 bptk.plot_scenarios(
#      48     scenario_managers=["sddsl_customer_acquisition"],
#      49     scenarios=["base","low_word_of_mouth","high_word_of_mouth"],
#      50     equations=["customers"],
#      51     series_names={
#      52         "sddsl_customer_acquisition_base_customers":"Base",
#      53         "sddsl_customer_acquisition_low_word_of_mouth_customers":"Low Word of Mouth",
#      54         "sddsl_customer_acquisition_high_word_of_mouth_customers":"High Word of Mouth",
#      55     }
#      56 )
#
# File C:\Repos\impact_assessment\venv\Lib\site-packages\BPTK_Py\bptk.py:895, in bptk.plot_scenarios(self, scenarios, scenario_managers, agents, agent_states, agent_properties, agent_property_types, equations, kind, alpha, stacked, freq, start_date, title, visualize_from_period, visualize_to_period, x_label, y_label, series_names, progress_bar, return_df, format)
#     833 def plot_scenarios(self, scenarios, scenario_managers, agents=[], agent_states=[], agent_properties=[],
#     834                    agent_property_types=[], equations=[],
#     835                    kind=None,
#    (...)    842                    format="plot"
#     843                   ):
#     845     """Plot scenarios for SD, ABM and hybrid models.
#     846
#     847     Args:
#    (...)    892         Dataframe with simulation results if return_df=True.
#     893      """
# --> 895     df = self.run_scenarios(scenarios=scenarios,
#     896                               scenario_managers=scenario_managers,
#     897                               agents=agents,
#     898                               agent_states=agent_states,
#     899                               agent_properties=agent_properties,
#     900                               agent_property_types=agent_property_types,
#     901                               equations=equations,
#     902                               series_names=series_names,
#     903                               progress_bar=progress_bar
#     904                              )
#     906     return self.visualizer.plot(df=df,
#     907                                 return_df=return_df,
#     908                                 format=format,
#    (...)    919                                 series_names=series_names
#     920                                 )
#
# File C:\Repos\impact_assessment\venv\Lib\site-packages\BPTK_Py\bptk.py:820, in bptk.run_scenarios(self, scenarios, scenario_managers, agents, agent_states, agent_properties, agent_property_types, equations, series_names, progress_bar, return_format)
#     817     if return_format=="json":
#     818         df = json.dumps(df,indent=2)
# --> 820 if len(df) == 0:
#     821     log("[ERROR] No output data produced.")
#     822     return None
#
# TypeError: object of type 'NoneType' has no len()
